# %% [markdown]
# # CIE_4140_Lecture_3_3_Python #

# %% [markdown]
# ## Example 1: A harmonic load ##

# %%
import sympy as sp

# %%
u = sp.symbols('u',cls=sp.Function)
omega_n, F_0, m, Omega, zeta = sp.symbols('omega_n, F_0, m, Omega, zeta',real=True,positive=True)
t = sp.symbols('t',real=True)
u_0, v_0 = sp.symbols('u_0, v_0')

# %% [markdown]
# Equation of moation:

# %%
Equation_of_Motion= sp.Eq(sp.diff(u(t),t,2)+2*zeta*omega_n*sp.diff(u(t),t)+omega_n **2 * u(t),F_0*sp.cos(Omega*t)/m)
display(Equation_of_Motion)
# Out:
# Eq(omega_n**2*u(t) + 2*omega_n*zeta*Derivative(u(t), t) + Derivative(u(t), (t, 2)), F_0*cos(Omega*t)/m)

# %% [markdown]
# Load:

# %%
sp.plot(1*sp.sin(1.1*t)/1,(t,0,200));

# %% [markdown]
# Calculation of Duhamel integral (for some reason this cell only succeeds on the second try,this bug is reported https://github.com/sympy/sympy/issues/24518)

# %%
omega_1, t_tilda = sp.symbols('omega_1, t_tilda',real=True,positive=True)
u_forced = sp.simplify(F_0/m/omega_1 *sp.integrate(sp.sin(Omega*t_tilda)*sp.exp(-zeta*omega_n*(t-t_tilda))*sp.sin(omega_1*(t-t_tilda)),(t_tilda,0,t)))
display(u_forced)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     478         try:
# --> 479             return self._assumptions[fact]
#     480         except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     478         try:
# --> 479             return self._assumptions[fact]
#     480         except KeyError:
#
# KeyError: 'integer'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     478         try:
# --> 479             return self._assumptions[fact]
#     480         except KeyError:
#
# KeyError: 'extended_positive'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     478         try:
# --> 479             return self._assumptions[fact]
#     480         except KeyError:
#
# KeyError: 'extended_negative'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25316\1892074096.py in <module>
#       1 omega_1, t_tilda = sp.symbols('omega_1, t_tilda',real=True,positive=True)
# ----> 2 u_forced = sp.simplify(F_0/m/omega_1 *sp.integrate(sp.sin(Omega*t_tilda)*sp.exp(-zeta*omega_n*(t-t_tilda))*sp.sin(omega_1*(t-t_tilda)),(t_tilda,0,t)))
#       3 display(u_forced)
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\integrals.py in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1564
#    1565     if isinstance(integral, Integral):
# -> 1566         return integral.doit(**doit_flags)
#    1567     else:
#    1568         new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\integrals.py in doit(self, **hints)
#     611                     antideriv = None
#     612                 else:
# --> 613                     antideriv = self._eval_integral(
#     614                         function, xab[0], **eval_kwargs)
#     615                     if antideriv is None and meijerg is True:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds, final)
#    1105             if h is None and manual is not False:
#    1106                 try:
# -> 1107                     result = manualintegrate(g, x)
#    1108                     if result is not None and not isinstance(result, Integral):
#    1109                         if result.has(Integral) and not manual:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in manualintegrate(f, var)
#    1683     sympy.integrals.integrals.Integral
#    1684     """
# -> 1685     result = _manualintegrate(integral_steps(f, var))
#    1686     # Clear the cache of u-parts
#    1687     _parts_u_cache.clear()
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     344             debug("Rule {}: {}".format(count, rule))
#     345
# --> 346             result = rule(integral)
#     347             if (result and not isinstance(result, DontKnowRule) and
#     348                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in conditioned_rl(expr)
#      28     def conditioned_rl(expr):
#      29         if cond(expr):
# ---> 30             return rule(expr)
#      31         else:
#      32             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _rewriter(integral)
#     302             rewritten = rewrite(*integral)
#     303             if rewritten != integrand:
# --> 304                 substep = integral_steps(rewritten, symbol)
#     305                 if not isinstance(substep, DontKnowRule) and substep:
#     306                     return RewriteRule(
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      90     def switch_rl(expr):
#      91         rl = ruledict.get(key(expr), identity)
# ---> 92         return rl(expr)
#      93     return switch_rl
#      94
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in mul_rule(integral)
#     530     # Constant times function case
#     531     coeff, f = integrand.as_independent(symbol)
# --> 532     next_step = integral_steps(f, symbol)
#     533
#     534     if coeff != 1 and next_step is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     344             debug("Rule {}: {}".format(count, rule))
#     345
# --> 346             result = rule(integral)
#     347             if (result and not isinstance(result, DontKnowRule) and
#     348                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in conditioned_rl(expr)
#      28     def conditioned_rl(expr):
#      29         if cond(expr):
# ---> 30             return rule(expr)
#      31         else:
#      32             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in parts_rule(integral)
#     697         u, dv, v, du, v_step = steps[0]
#     698         rule = PartsRule(u, dv, v_step,
# --> 699                          make_second_step(steps[1:], v * du),
#     700                          integrand, symbol)
#     701         if (constant != 1) and rule:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in make_second_step(steps, integrand)
#     688                              integrand, symbol)
#     689         else:
# --> 690             steps = integral_steps(integrand, symbol)
#     691             if steps:
#     692                 return steps
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      90     def switch_rl(expr):
#      91         rl = ruledict.get(key(expr), identity)
# ---> 92         return rl(expr)
#      93     return switch_rl
#      94
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in mul_rule(integral)
#     530     # Constant times function case
#     531     coeff, f = integrand.as_independent(symbol)
# --> 532     next_step = integral_steps(f, symbol)
#     533
#     534     if coeff != 1 and next_step is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     344             debug("Rule {}: {}".format(count, rule))
#     345
# --> 346             result = rule(integral)
#     347             if (result and not isinstance(result, DontKnowRule) and
#     348                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in conditioned_rl(expr)
#      28     def conditioned_rl(expr):
#      29         if cond(expr):
# ---> 30             return rule(expr)
#      31         else:
#      32             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _rewriter(integral)
#     302             rewritten = rewrite(*integral)
#     303             if rewritten != integrand:
# --> 304                 substep = integral_steps(rewritten, symbol)
#     305                 if not isinstance(substep, DontKnowRule) and substep:
#     306                     return RewriteRule(
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      90     def switch_rl(expr):
#      91         rl = ruledict.get(key(expr), identity)
# ---> 92         return rl(expr)
#      93     return switch_rl
#      94
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in add_rule(integral)
#     521 def add_rule(integral):
#     522     integrand, symbol = integral
# --> 523     results = [integral_steps(g, symbol)
#     524               for g in integrand.as_ordered_terms()]
#     525     return None if None in results else AddRule(results, integrand, symbol)
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in <listcomp>(.0)
#     521 def add_rule(integral):
#     522     integrand, symbol = integral
# --> 523     results = [integral_steps(g, symbol)
#     524               for g in integrand.as_ordered_terms()]
#     525     return None if None in results else AddRule(results, integrand, symbol)
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      90     def switch_rl(expr):
#      91         rl = ruledict.get(key(expr), identity)
# ---> 92         return rl(expr)
#      93     return switch_rl
#      94
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in mul_rule(integral)
#     530     # Constant times function case
#     531     coeff, f = integrand.as_independent(symbol)
# --> 532     next_step = integral_steps(f, symbol)
#     533
#     534     if coeff != 1 and next_step is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     344             debug("Rule {}: {}".format(count, rule))
#     345
# --> 346             result = rule(integral)
#     347             if (result and not isinstance(result, DontKnowRule) and
#     348                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in conditioned_rl(expr)
#      28     def conditioned_rl(expr):
#      29         if cond(expr):
# ---> 30             return rule(expr)
#      31         else:
#      32             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in parts_rule(integral)
#     697         u, dv, v, du, v_step = steps[0]
#     698         rule = PartsRule(u, dv, v_step,
# --> 699                          make_second_step(steps[1:], v * du),
#     700                          integrand, symbol)
#     701         if (constant != 1) and rule:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in make_second_step(steps, integrand)
#     688                              integrand, symbol)
#     689         else:
# --> 690             steps = integral_steps(integrand, symbol)
#     691             if steps:
#     692                 return steps
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      90     def switch_rl(expr):
#      91         rl = ruledict.get(key(expr), identity)
# ---> 92         return rl(expr)
#      93     return switch_rl
#      94
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in mul_rule(integral)
#     530     # Constant times function case
#     531     coeff, f = integrand.as_independent(symbol)
# --> 532     next_step = integral_steps(f, symbol)
#     533
#     534     if coeff != 1 and next_step is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     344             debug("Rule {}: {}".format(count, rule))
#     345
# --> 346             result = rule(integral)
#     347             if (result and not isinstance(result, DontKnowRule) and
#     348                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in conditioned_rl(expr)
#      28     def conditioned_rl(expr):
#      29         if cond(expr):
# ---> 30             return rule(expr)
#      31         else:
#      32             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _rewriter(integral)
#     302             rewritten = rewrite(*integral)
#     303             if rewritten != integrand:
# --> 304                 substep = integral_steps(rewritten, symbol)
#     305                 if not isinstance(substep, DontKnowRule) and substep:
#     306                     return RewriteRule(
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      90     def switch_rl(expr):
#      91         rl = ruledict.get(key(expr), identity)
# ---> 92         return rl(expr)
#      93     return switch_rl
#      94
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in add_rule(integral)
#     521 def add_rule(integral):
#     522     integrand, symbol = integral
# --> 523     results = [integral_steps(g, symbol)
#     524               for g in integrand.as_ordered_terms()]
#     525     return None if None in results else AddRule(results, integrand, symbol)
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in <listcomp>(.0)
#     521 def add_rule(integral):
#     522     integrand, symbol = integral
# --> 523     results = [integral_steps(g, symbol)
#     524               for g in integrand.as_ordered_terms()]
#     525     return None if None in results else AddRule(results, integrand, symbol)
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      90     def switch_rl(expr):
#      91         rl = ruledict.get(key(expr), identity)
# ---> 92         return rl(expr)
#      93     return switch_rl
#      94
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in mul_rule(integral)
#     530     # Constant times function case
#     531     coeff, f = integrand.as_independent(symbol)
# --> 532     next_step = integral_steps(f, symbol)
#     533
#     534     if coeff != 1 and next_step is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     344             debug("Rule {}: {}".format(count, rule))
#     345
# --> 346             result = rule(integral)
#     347             if (result and not isinstance(result, DontKnowRule) and
#     348                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in conditioned_rl(expr)
#      28     def conditioned_rl(expr):
#      29         if cond(expr):
# ---> 30             return rule(expr)
#      31         else:
#      32             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in parts_rule(integral)
#     697         u, dv, v, du, v_step = steps[0]
#     698         rule = PartsRule(u, dv, v_step,
# --> 699                          make_second_step(steps[1:], v * du),
#     700                          integrand, symbol)
#     701         if (constant != 1) and rule:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in make_second_step(steps, integrand)
#     688                              integrand, symbol)
#     689         else:
# --> 690             steps = integral_steps(integrand, symbol)
#     691             if steps:
#     692                 return steps
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      90     def switch_rl(expr):
#      91         rl = ruledict.get(key(expr), identity)
# ---> 92         return rl(expr)
#      93     return switch_rl
#      94
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in mul_rule(integral)
#     530     # Constant times function case
#     531     coeff, f = integrand.as_independent(symbol)
# --> 532     next_step = integral_steps(f, symbol)
#     533
#     534     if coeff != 1 and next_step is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     344             debug("Rule {}: {}".format(count, rule))
#     345
# --> 346             result = rule(integral)
#     347             if (result and not isinstance(result, DontKnowRule) and
#     348                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in conditioned_rl(expr)
#      28     def conditioned_rl(expr):
#      29         if cond(expr):
# ---> 30             return rule(expr)
#      31         else:
#      32             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _rewriter(integral)
#     302             rewritten = rewrite(*integral)
#     303             if rewritten != integrand:
# --> 304                 substep = integral_steps(rewritten, symbol)
#     305                 if not isinstance(substep, DontKnowRule) and substep:
#     306                     return RewriteRule(
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      90     def switch_rl(expr):
#      91         rl = ruledict.get(key(expr), identity)
# ---> 92         return rl(expr)
#      93     return switch_rl
#      94
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in add_rule(integral)
#     521 def add_rule(integral):
#     522     integrand, symbol = integral
# --> 523     results = [integral_steps(g, symbol)
#     524               for g in integrand.as_ordered_terms()]
#     525     return None if None in results else AddRule(results, integrand, symbol)
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in <listcomp>(.0)
#     521 def add_rule(integral):
#     522     integrand, symbol = integral
# --> 523     results = [integral_steps(g, symbol)
#     524               for g in integrand.as_ordered_terms()]
#     525     return None if None in results else AddRule(results, integrand, symbol)
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      90     def switch_rl(expr):
#      91         rl = ruledict.get(key(expr), identity)
# ---> 92         return rl(expr)
#      93     return switch_rl
#      94
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in mul_rule(integral)
#     530     # Constant times function case
#     531     coeff, f = integrand.as_independent(symbol)
# --> 532     next_step = integral_steps(f, symbol)
#     533
#     534     if coeff != 1 and next_step is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     344             debug("Rule {}: {}".format(count, rule))
#     345
# --> 346             result = rule(integral)
#     347             if (result and not isinstance(result, DontKnowRule) and
#     348                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in conditioned_rl(expr)
#      28     def conditioned_rl(expr):
#      29         if cond(expr):
# ---> 30             return rule(expr)
#      31         else:
#      32             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in parts_rule(integral)
#     697         u, dv, v, du, v_step = steps[0]
#     698         rule = PartsRule(u, dv, v_step,
# --> 699                          make_second_step(steps[1:], v * du),
#     700                          integrand, symbol)
#     701         if (constant != 1) and rule:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in make_second_step(steps, integrand)
#     688                              integrand, symbol)
#     689         else:
# --> 690             steps = integral_steps(integrand, symbol)
#     691             if steps:
#     692                 return steps
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      90     def switch_rl(expr):
#      91         rl = ruledict.get(key(expr), identity)
# ---> 92         return rl(expr)
#      93     return switch_rl
#      94
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in mul_rule(integral)
#     530     # Constant times function case
#     531     coeff, f = integrand.as_independent(symbol)
# --> 532     next_step = integral_steps(f, symbol)
#     533
#     534     if coeff != 1 and next_step is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     344             debug("Rule {}: {}".format(count, rule))
#     345
# --> 346             result = rule(integral)
#     347             if (result and not isinstance(result, DontKnowRule) and
#     348                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _rewriter(integral)
#     302             rewritten = rewrite(*integral)
#     303             if rewritten != integrand:
# --> 304                 substep = integral_steps(rewritten, symbol)
#     305                 if not isinstance(substep, DontKnowRule) and substep:
#     306                     return RewriteRule(
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      90     def switch_rl(expr):
#      91         rl = ruledict.get(key(expr), identity)
# ---> 92         return rl(expr)
#      93     return switch_rl
#      94
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in add_rule(integral)
#     521 def add_rule(integral):
#     522     integrand, symbol = integral
# --> 523     results = [integral_steps(g, symbol)
#     524               for g in integrand.as_ordered_terms()]
#     525     return None if None in results else AddRule(results, integrand, symbol)
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in <listcomp>(.0)
#     521 def add_rule(integral):
#     522     integrand, symbol = integral
# --> 523     results = [integral_steps(g, symbol)
#     524               for g in integrand.as_ordered_terms()]
#     525     return None if None in results else AddRule(results, integrand, symbol)
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      90     def switch_rl(expr):
#      91         rl = ruledict.get(key(expr), identity)
# ---> 92         return rl(expr)
#      93     return switch_rl
#      94
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in mul_rule(integral)
#     530     # Constant times function case
#     531     coeff, f = integrand.as_independent(symbol)
# --> 532     next_step = integral_steps(f, symbol)
#     533
#     534     if coeff != 1 and next_step is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     344             debug("Rule {}: {}".format(count, rule))
#     345
# --> 346             result = rule(integral)
# ...
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     344             debug("Rule {}: {}".format(count, rule))
#     345
# --> 346             result = rule(integral)
#     347             if (result and not isinstance(result, DontKnowRule) and
#     348                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in conditioned_rl(expr)
#      28     def conditioned_rl(expr):
#      29         if cond(expr):
# ---> 30             return rule(expr)
#      31         else:
#      32             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in parts_rule(integral)
#     633     constant, integrand = integrand.as_coeff_Mul()
#     634
# --> 635     result = _parts_rule(integrand, symbol)
#     636
#     637     steps = []
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _parts_rule(integrand, symbol)
#     623             if accept:
#     624                 du = u.diff(symbol)
# --> 625                 v_step = integral_steps(simplify(dv), symbol)
#     626                 if not contains_dont_know(v_step):
#     627                     v = _manualintegrate(v_step)
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     344             debug("Rule {}: {}".format(count, rule))
#     345
# --> 346             result = rule(integral)
#     347             if (result and not isinstance(result, DontKnowRule) and
#     348                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in substitution_rule(integral)
#    1120         ways = []
#    1121         for u_func, c, substituted in substitutions:
# -> 1122             subrule = integral_steps(substituted, u_var)
#    1123             count = count + 1
#    1124             debug("Rule {}: {}".format(count, subrule))
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1315         return _integral_is_subclass
#    1316
# -> 1317     result = do_one(
#    1318         null_safe(special_function_rule),
#    1319         null_safe(switch(key, {
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      80     def do_one_rl(expr):
#      81         for rl in rules:
# ---> 82             result = rl(expr)
#      83             if result != expr:
#      84                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      60     """ Return original expr if rule returns None """
#      61     def null_safe_rl(expr):
# ---> 62         result = rule(expr)
#      63         if result is None:
#      64             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in special_function_rule(integral)
#     429         (Mul, exp(a*symbol + b)/symbol, None, EiRule),
#     430         (Mul, cos(a*symbol + b)/symbol, None, CiRule),
# --> 431         (Mul, cosh(a*symbol + b)/symbol, None, ChiRule),
#     432         (Mul, sin(a*symbol + b)/symbol, None, SiRule),
#     433         (Mul, sinh(a*symbol + b)/symbol, None, ShiRule),
#
# ~\Anaconda3\lib\site-packages\sympy\core\decorators.py in _func(self, other)
#     234             if not isinstance(other, expectedcls):
#     235                 return retval
# --> 236             return func(self, other)
#     237
#     238         return _func
#
# ~\Anaconda3\lib\site-packages\sympy\core\decorators.py in binary_op_wrapper(self, other)
#     104                     if f is not None:
#     105                         return f(self)
# --> 106             return func(self, other)
#     107         return binary_op_wrapper
#     108     return priority_decorator
#
# ~\Anaconda3\lib\site-packages\sympy\core\expr.py in __truediv__(self, other)
#     251             return denom
#     252         else:
# --> 253             return Mul(self, denom)
#     254
#     255     @sympify_return([('other', 'Expr')], NotImplemented)
#
# ~\Anaconda3\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# ~\Anaconda3\lib\site-packages\sympy\core\operations.py in __new__(cls, evaluate, _sympify, *args)
#      96             return args[0]
#      97
# ---> 98         c_part, nc_part, order_symbols = cls.flatten(args)
#      99         is_commutative = not nc_part
#     100         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# ~\Anaconda3\lib\site-packages\sympy\core\mul.py in flatten(cls, seq)
#     283                 seq = [a, b]
#     284             assert a is not S.One
# --> 285             if not a.is_zero and a.is_Rational:
#     286                 r, b = b.as_coeff_Mul()
#     287                 if b.is_Add:
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     481             if self._assumptions is self.default_assumptions:
#     482                 self._assumptions = self.default_assumptions.copy()
# --> 483             return _ask(fact, self)
#     484
#     485     getit.func_name = as_property(fact)
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     542         pass
#     543     else:
# --> 544         a = evaluate(obj)
#     545         if a is not None:
#     546             assumptions.deduce_all_facts(((fact, a),))
#
# ~\Anaconda3\lib\site-packages\sympy\functions\elementary\hyperbolic.py in _eval_is_real(self)
#     447         # if not, check if the imaginary part is a number
#     448         re, im = arg.as_real_imag()
# --> 449         return (im%pi).is_zero
#     450
#     451     def _eval_is_positive(self):
#
# ~\Anaconda3\lib\site-packages\sympy\core\decorators.py in _func(self, other)
#     234             if not isinstance(other, expectedcls):
#     235                 return retval
# --> 236             return func(self, other)
#     237
#     238         return _func
#
# ~\Anaconda3\lib\site-packages\sympy\core\decorators.py in binary_op_wrapper(self, other)
#     104                     if f is not None:
#     105                         return f(self)
# --> 106             return func(self, other)
#     107         return binary_op_wrapper
#     108     return priority_decorator
#
# ~\Anaconda3\lib\site-packages\sympy\core\expr.py in __mod__(self, other)
#     265     @call_highest_priority('__rmod__')
#     266     def __mod__(self, other):
# --> 267         return Mod(self, other)
#     268
#     269     @sympify_return([('other', 'Expr')], NotImplemented)
#
# ~\Anaconda3\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# ~\Anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     474
#     475         evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 476         result = super().__new__(cls, *args, **options)
#     477         if evaluate and isinstance(result, cls) and result.args:
#     478             pr2 = min(cls._should_evalf(a) for a in result.args)
#
# ~\Anaconda3\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# ~\Anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     286
#     287         if evaluate:
# --> 288             evaluated = cls.eval(*args)
#     289             if evaluated is not None:
#     290                 return evaluated
#
# ~\Anaconda3\lib\site-packages\sympy\core\mod.py in eval(cls, p, q)
#     100                     break
#     101
# --> 102         rv = doit(p, q)
#     103         if rv is not None:
#     104             return rv
#
# ~\Anaconda3\lib\site-packages\sympy\core\mod.py in doit(p, q)
#      69             # by ratio
#      70             r = p/q
# ---> 71             if r.is_integer:
#      72                 return S.Zero
#      73             try:
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     481             if self._assumptions is self.default_assumptions:
#     482                 self._assumptions = self.default_assumptions.copy()
# --> 483             return _ask(fact, self)
#     484
#     485     getit.func_name = as_property(fact)
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     542         pass
#     543     else:
# --> 544         a = evaluate(obj)
#     545         if a is not None:
#     546             assumptions.deduce_all_facts(((fact, a),))
#
# ~\Anaconda3\lib\site-packages\sympy\core\expr.py in _eval_is_positive(self)
#     836         if finite is False:
#     837             return False
# --> 838         extended_positive = self.is_extended_positive
#     839         if finite is True:
#     840             return extended_positive
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     481             if self._assumptions is self.default_assumptions:
#     482                 self._assumptions = self.default_assumptions.copy()
# --> 483             return _ask(fact, self)
#     484
#     485     getit.func_name = as_property(fact)
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     542         pass
#     543     else:
# --> 544         a = evaluate(obj)
#     545         if a is not None:
#     546             assumptions.deduce_all_facts(((fact, a),))
#
# ~\Anaconda3\lib\site-packages\sympy\core\expr.py in _eval_is_negative(self)
#     846         if finite is False:
#     847             return False
# --> 848         extended_negative = self.is_extended_negative
#     849         if finite is True:
#     850             return extended_negative
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     481             if self._assumptions is self.default_assumptions:
#     482                 self._assumptions = self.default_assumptions.copy()
# --> 483             return _ask(fact, self)
#     484
#     485     getit.func_name = as_property(fact)
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     542         pass
#     543     else:
# --> 544         a = evaluate(obj)
#     545         if a is not None:
#     546             assumptions.deduce_all_facts(((fact, a),))
#
# ~\Anaconda3\lib\site-packages\sympy\core\mul.py in _eval_is_extended_real(self)
#    1436
#    1437     def _eval_is_extended_real(self):
# -> 1438         return self._eval_real_imag(True)
#    1439
#    1440     def _eval_real_imag(self, real):
#
# ~\Anaconda3\lib\site-packages\sympy\core\mul.py in _eval_real_imag(self, real)
#    1445             if (t.is_complex or t.is_infinite) is False and t.is_extended_real is False:
#    1446                 return False
# -> 1447             elif t.is_imaginary:  # I
#    1448                 real = not real
#    1449             elif t.is_extended_real:  # 2
#
# ~\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     477     def getit(self):
#     478         try:
# --> 479             return self._assumptions[fact]
#     480         except KeyError:
#     481             if self._assumptions is self.default_assumptions:
#
# KeyboardInterrupt:

# %%
u_forced = u_forced.subs(omega_1,omega_n * sp.sqrt(1-zeta**2))
display(u_forced)
# Out:
# F_0*(Omega**3*sin(omega_n*t*sqrt(1 - zeta**2)) - Omega**2*omega_n*sqrt(1 - zeta**2)*exp(omega_n*t*zeta)*sin(Omega*t) + Omega*omega_n**2*zeta**2*sin(omega_n*t*sqrt(1 - zeta**2)) - 2*Omega*omega_n**2*zeta*sqrt(1 - zeta**2)*exp(omega_n*t*zeta)*cos(Omega*t) + 2*Omega*omega_n**2*zeta*sqrt(1 - zeta**2)*cos(omega_n*t*sqrt(1 - zeta**2)) - Omega*omega_n**2*(1 - zeta**2)*sin(omega_n*t*sqrt(1 - zeta**2)) + omega_n**3*zeta**2*sqrt(1 - zeta**2)*exp(omega_n*t*zeta)*sin(Omega*t) + omega_n**3*(1 - zeta**2)**(3/2)*exp(omega_n*t*zeta)*sin(Omega*t))*exp(-omega_n*t*zeta)/(m*omega_n*sqrt(1 - zeta**2)*(Omega**4 + 2*Omega**2*omega_n**2*zeta**2 - 2*Omega**2*omega_n**2*(1 - zeta**2) + omega_n**4*zeta**4 + 2*omega_n**4*zeta**2*(1 - zeta**2) + omega_n**4*(1 - zeta**2)**2))

# %%
response = (sp.exp(-zeta*omega_n*t)*(u_0*sp.cos(omega_n*t)+
                                    (v_0/(omega_n * sp.sqrt(1-zeta**2))+
                                     u_0*zeta*omega_n/(omega_n * sp.sqrt(1-zeta**2)))*sp.sin(omega_n*t))+
            u_forced)
display(response)
# Out:
# F_0*(Omega**3*sin(omega_n*t*sqrt(1 - zeta**2)) - Omega**2*omega_n*sqrt(1 - zeta**2)*exp(omega_n*t*zeta)*sin(Omega*t) + Omega*omega_n**2*zeta**2*sin(omega_n*t*sqrt(1 - zeta**2)) - 2*Omega*omega_n**2*zeta*sqrt(1 - zeta**2)*exp(omega_n*t*zeta)*cos(Omega*t) + 2*Omega*omega_n**2*zeta*sqrt(1 - zeta**2)*cos(omega_n*t*sqrt(1 - zeta**2)) - Omega*omega_n**2*(1 - zeta**2)*sin(omega_n*t*sqrt(1 - zeta**2)) + omega_n**3*zeta**2*sqrt(1 - zeta**2)*exp(omega_n*t*zeta)*sin(Omega*t) + omega_n**3*(1 - zeta**2)**(3/2)*exp(omega_n*t*zeta)*sin(Omega*t))*exp(-omega_n*t*zeta)/(m*omega_n*sqrt(1 - zeta**2)*(Omega**4 + 2*Omega**2*omega_n**2*zeta**2 - 2*Omega**2*omega_n**2*(1 - zeta**2) + omega_n**4*zeta**4 + 2*omega_n**4*zeta**2*(1 - zeta**2) + omega_n**4*(1 - zeta**2)**2)) + (u_0*cos(omega_n*t) + (u_0*zeta/sqrt(1 - zeta**2) + v_0/(omega_n*sqrt(1 - zeta**2)))*sin(omega_n*t))*exp(-omega_n*t*zeta)

# %%
sp.plot(response.subs([(u_0,0.1),(v_0,0.1),(F_0,1),(omega_n,1),(zeta,0.05),(m,1),(Omega,1.2)]), (t , 0 , 200));

# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
response_func = sp.lambdify((u_0,v_0,F_0,omega_n,zeta,m,Omega,t),response)

# %%
fig, ax = plt.subplots()
tdata = np.linspace(0,200,500)
line, = ax.plot([], [])
ax.set_xlim(0, 1)
ax.set_ylim(-5, 5)

def update(frame):
    ydata = response_func(u_0=1,v_0=0,m=1,omega_n=1,F_0=1,zeta=0.05,Omega=frame,t=tdata)
    ax.set_title("Displacement versus time for $\Omega$ = "+str(np.round(frame,2)))
    line.set_data(tdata, ydata)

ani = FuncAnimation(fig, update, frames=np.linspace(1.1,1.6,100),interval = 100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
tdata = np.linspace(0,200,500)
line, = ax.plot([], [])
ax.set_xlim(0, 200)
ax.set_ylim(-9, 9)

def update(frame):
    ydata = response_func(u_0=1,v_0=0,m=1,omega_n=1,F_0=1,zeta=frame,Omega=1.1,t=tdata)
    ax.set_title("Displacement versus time for $\zeta$ = "+str(np.round(frame,2)))
    line.set_data(tdata, ydata)

ani = FuncAnimation(fig, update, frames=np.linspace(0.01,0.3,100),interval = 100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Example 2: a suddenly applied constant load ##

# %% [markdown]
# Equation of motion:

# %%
t = sp.symbols('t',real=True)
Equation_of_Motion= sp.Eq(sp.diff(u(t),t,2)+2*zeta*omega_n*sp.diff(u(t),t)+omega_n **2 * u(t),F_0*sp.Heaviside(t)/m)
display(Equation_of_Motion)
# Out:
# Eq(omega_n**2*u(t) + 2*omega_n*zeta*Derivative(u(t), t) + Derivative(u(t), (t, 2)), F_0*Heaviside(t)/m)

# %% [markdown]
# Load

# %%
sp.plot(sp.Heaviside(t-0),(t,-50,300));
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Calculation of Duhamel integral

# %%
u_forced = sp.simplify(F_0/m/omega_1 *sp.integrate(sp.exp(-zeta*omega_n*(t-t_tilda))*sp.sin(omega_1*(t-t_tilda)),(t_tilda,0,t)))
display(u_forced)
# Out:
# F_0*(omega_1*exp(omega_n*t*zeta) - omega_1*cos(omega_1*t) - omega_n*zeta*sin(omega_1*t))*exp(-omega_n*t*zeta)/(m*omega_1*(omega_1**2 + omega_n**2*zeta**2))

# %% [markdown]
# The total solution

# %%
response = (sp.exp(-zeta*omega_n*t)*(u_0*sp.cos(omega_n*t)+
                                    (v_0/(omega_n * sp.sqrt(1-zeta**2))+
                                     u_0*zeta*omega_n/(omega_n * sp.sqrt(1-zeta**2)))*sp.sin(omega_n*t))+
            u_forced.subs(omega_1,omega_n*sp.sqrt(1-zeta**2)))
display(response)
# Out:
# F_0*(-omega_n*zeta*sin(omega_n*t*sqrt(1 - zeta**2)) + omega_n*sqrt(1 - zeta**2)*exp(omega_n*t*zeta) - omega_n*sqrt(1 - zeta**2)*cos(omega_n*t*sqrt(1 - zeta**2)))*exp(-omega_n*t*zeta)/(m*omega_n*sqrt(1 - zeta**2)*(omega_n**2*zeta**2 + omega_n**2*(1 - zeta**2))) + (u_0*cos(omega_n*t) + (u_0*zeta/sqrt(1 - zeta**2) + v_0/(omega_n*sqrt(1 - zeta**2)))*sin(omega_n*t))*exp(-omega_n*t*zeta)

# %%
p0 = sp.plotting.plot(response.subs([(u_0,0),(v_0,0),(F_0,1),(m,1),(omega_n,1),(zeta,0   )]), (t , 0 , 50),label='$\zeta$=0'    ,legend=True,show=False)
p1 = sp.plotting.plot(response.subs([(u_0,0),(v_0,0),(F_0,1),(m,1),(omega_n,1),(zeta,0.05)]), (t , 0 , 50),label='$\zeta$=0.05' ,show=False)
p2 = sp.plotting.plot(response.subs([(u_0,0),(v_0,0),(F_0,1),(m,1),(omega_n,1),(zeta,0.1 )]), (t , 0 , 50),label='$\zeta$=0.1'  ,show=False)
p0.append(p1[0])
p0.append(p2[0])
p0.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
response_func = sp.lambdify((u_0,v_0,F_0,omega_n,zeta,m,t),response)

# %%
fig, ax = plt.subplots()
tdata = np.linspace(0,200,500)
line, = ax.plot([], [])
ax.set_xlim(0, 200)
ax.set_ylim(0,2)

def update(frame):
    ydata = response_func(u_0=0,v_0=0,m=1,omega_n=1,F_0=1,zeta=frame,t=tdata)
    ax.set_title("Displacement versus time for $\zeta$ = "+str(np.round(frame,2)))
    line.set_data(tdata, ydata)

ani = FuncAnimation(fig, update, frames=np.linspace(0.,0.2,100),interval = 100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Example 3: a suddenly applied constant load of finite duration ##

# %% [markdown]
# Equation of motion

# %%
dt = sp.symbols('dt',real=True,positive=True)
Equation_of_Motion= sp.Eq(sp.diff(u(t),t,2)+2*zeta*omega_n*sp.diff(u(t),t)+omega_n **2 * u(t),F_0*(sp.Heaviside(t)-sp.Heaviside(t-dt))/m)
display(Equation_of_Motion)
# Out:
# Eq(omega_n**2*u(t) + 2*omega_n*zeta*Derivative(u(t), t) + Derivative(u(t), (t, 2)), F_0*(Heaviside(t) - Heaviside(-dt + t))/m)

# %% [markdown]
# Load:

# %%
sp.plot(sp.Heaviside(t)-sp.Heaviside(t-4*sp.pi),(t,-50,30));
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Calculation of the Duhamel integral

# %% [markdown]
# if $t<dt$ then:

# %%
u_forced_1 = sp.simplify(F_0/m/omega_1 *sp.integrate(sp.exp(-zeta*omega_n*(t-t_tilda))*sp.sin(omega_1*(t-t_tilda)),(t_tilda,0,t)))
display(u_forced_1)
# Out:
# F_0*(omega_1*exp(omega_n*t*zeta) - omega_1*cos(omega_1*t) - omega_n*zeta*sin(omega_1*t))*exp(-omega_n*t*zeta)/(m*omega_1*(omega_1**2 + omega_n**2*zeta**2))

# %% [markdown]
# if $t>dt$ then:

# %%
u_forced_2 = sp.simplify(F_0/m/omega_1 *sp.integrate(sp.exp(-zeta*omega_n*(t-t_tilda))*sp.sin(omega_1*(t-t_tilda)),(t_tilda,0,dt)))
display(u_forced_2)
# Out:
# F_0*(omega_1*exp(dt*omega_n*zeta)*cos(omega_1*(dt - t)) - omega_1*cos(omega_1*t) - omega_n*zeta*exp(dt*omega_n*zeta)*sin(omega_1*(dt - t)) - omega_n*zeta*sin(omega_1*t))*exp(-omega_n*t*zeta)/(m*omega_1*(omega_1**2 + omega_n**2*zeta**2))

# %% [markdown]
# The total solution:

# %%
response = (sp.exp(-zeta*omega_n*t)*(u_0*sp.cos(omega_n*t)+
                                    (v_0/(omega_n * sp.sqrt(1-zeta**2))+
                                     u_0*zeta*omega_n/(omega_n * sp.sqrt(1-zeta**2)))*sp.sin(omega_n*t))+
            sp.Piecewise((u_forced_1.subs(omega_1,omega_n*sp.sqrt(1-zeta**2)),t<dt),
                         (u_forced_2.subs(omega_1,omega_n*sp.sqrt(1-zeta**2)),True)))
display(response)
# Out:
# (u_0*cos(omega_n*t) + (u_0*zeta/sqrt(1 - zeta**2) + v_0/(omega_n*sqrt(1 - zeta**2)))*sin(omega_n*t))*exp(-omega_n*t*zeta) + Piecewise((F_0*(-omega_n*zeta*sin(omega_n*t*sqrt(1 - zeta**2)) + omega_n*sqrt(1 - zeta**2)*exp(omega_n*t*zeta) - omega_n*sqrt(1 - zeta**2)*cos(omega_n*t*sqrt(1 - zeta**2)))*exp(-omega_n*t*zeta)/(m*omega_n*sqrt(1 - zeta**2)*(omega_n**2*zeta**2 + omega_n**2*(1 - zeta**2))), dt > t), (F_0*(-omega_n*zeta*exp(dt*omega_n*zeta)*sin(omega_n*sqrt(1 - zeta**2)*(dt - t)) - omega_n*zeta*sin(omega_n*t*sqrt(1 - zeta**2)) + omega_n*sqrt(1 - zeta**2)*exp(dt*omega_n*zeta)*cos(omega_n*sqrt(1 - zeta**2)*(dt - t)) - omega_n*sqrt(1 - zeta**2)*cos(omega_n*t*sqrt(1 - zeta**2)))*exp(-omega_n*t*zeta)/(m*omega_n*sqrt(1 - zeta**2)*(omega_n**2*zeta**2 + omega_n**2*(1 - zeta**2))), True))

# %%
response_func = sp.lambdify((u_0,v_0,F_0,omega_n,zeta,m,t,dt),response)

# %%
fig, ax = plt.subplots()
tdata = np.linspace(0,50,500)
line, = ax.plot([], [])
ax.set_xlim(0, 50)
ax.set_ylim(-2,2)

def update(frame):
    ydata = response_func(u_0=0,v_0=0,m=1,omega_n=1,F_0=1,zeta=0.05,dt=frame,t=tdata)
    ax.set_title("Displacement versus time for $dt$ = "+str(np.round(frame,2)))
    line.set_data(tdata, ydata)

ani = FuncAnimation(fig, update, frames=np.linspace(3*np.pi,5*np.pi,100),interval = 100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
tdata = np.linspace(0,50,500)
line, = ax.plot([], [])
ax.set_xlim(0, 50)
ax.set_ylim(-2,2)

def update(frame):
    ydata = response_func(u_0=0,v_0=0,m=1,omega_n=1,F_0=1,zeta=0,dt=frame,t=tdata)
    ax.set_title("Displacement versus time for $dt$ = "+str(np.round(frame,2)))
    line.set_data(tdata, ydata)

ani = FuncAnimation(fig, update, frames=np.linspace(3*np.pi,5*np.pi,100),interval = 100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
