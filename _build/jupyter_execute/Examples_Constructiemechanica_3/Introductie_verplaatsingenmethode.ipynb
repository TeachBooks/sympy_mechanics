# %% [markdown]
# # Introductie verplaatsingenmethode

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy as sp

# %%
a, b, c, k1, k2, k3 = sp.symbols('a b c k1 k2 k3')

# %%
Bg = sp.Matrix([[0,-1,-a],[0,-1,b],[-1,0,c]])
BgT = sp.transpose(Bg)
Dg = sp.Matrix([[k1,0,0],[0,k2,0],[0,0,k3]])
K = BgT*Dg*Bg
display(K)
F = K.inv()
display(F)
load = sp.Matrix([50,150,-5])
disp = F*load
disp_sol = disp.subs([(a,3),(b,2),(c,1),(k1,1000),(k2,2000),(k3,3000)])
display(disp_sol)
display(disp_sol.evalf())
# Out:
# Matrix([
# [   k3,           0,                       -c*k3],
# [    0,     k1 + k2,                 a*k1 - b*k2],
# [-c*k3, a*k1 - b*k2, a**2*k1 + b**2*k2 + c**2*k3]])
# Matrix([
# [(a**2*k1*k2 + 2*a*b*k1*k2 + b**2*k1*k2 + c**2*k1*k3 + c**2*k2*k3)/(a**2*k1*k2*k3 + 2*a*b*k1*k2*k3 + b**2*k1*k2*k3),  (-a*c*k1 + b*c*k2)/(a**2*k1*k2 + 2*a*b*k1*k2 + b**2*k1*k2),  (c*k1 + c*k2)/(a**2*k1*k2 + 2*a*b*k1*k2 + b**2*k1*k2)],
# [                                                        (-a*c*k1 + b*c*k2)/(a**2*k1*k2 + 2*a*b*k1*k2 + b**2*k1*k2), (a**2*k1 + b**2*k2)/(a**2*k1*k2 + 2*a*b*k1*k2 + b**2*k1*k2), (-a*k1 + b*k2)/(a**2*k1*k2 + 2*a*b*k1*k2 + b**2*k1*k2)],
# [                                                             (c*k1 + c*k2)/(a**2*k1*k2 + 2*a*b*k1*k2 + b**2*k1*k2),      (-a*k1 + b*k2)/(a**2*k1*k2 + 2*a*b*k1*k2 + b**2*k1*k2),      (k1 + k2)/(a**2*k1*k2 + 2*a*b*k1*k2 + b**2*k1*k2)]])
# Matrix([
# [671/30000],
# [519/10000],
# [ 57/10000]])
# Matrix([
# [0.0223666666666667],
# [            0.0519],
# [            0.0057]])
